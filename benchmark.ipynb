# %%
import pandas as pd

data = pd.read_csv("./result.csv")
data.head()
# Out:
#        filename  table-based without partitions  table-based with partitions  \
# 0  5_20_5_5_3_7                            54.0                         53.0
# 1  5_21_5_5_3_7                            89.0                         92.0
# 2  5_22_5_5_3_7                            64.0                        191.0
# 3  5_23_5_5_3_7                           228.0                        230.0
# 4  5_24_5_6_3_7                            79.0                         90.0
#
#    tag-based without partitions  tag-based with partitions
# 0                          42.0                       38.0
# 1                          90.0                       66.0
# 2                          63.0                       82.0
# 3                         356.0                      365.0
# 4                          62.0                       56.0

# %%
data = data.fillna(60000)

# %%
import seaborn as sns

sns.scatterplot(data=data, y="table-based without partitions", x="table-based with partitions")
sns.lineplot(data=pd.DataFrame({"x": [0, 60000], "y": [0, 60000]}), x="x", y="y")
# Out:
# <AxesSubplot:xlabel='table-based with partitions', ylabel='table-based without partitions'>

# %%
sns.scatterplot(data=data, y="tag-based without partitions", x="tag-based with partitions")
sns.lineplot(data=pd.DataFrame({"x": [0, 60000], "y": [0, 60000]}), x="x", y="y")
# Out:
# <AxesSubplot:xlabel='tag-based with partitions', ylabel='tag-based without partitions'>
